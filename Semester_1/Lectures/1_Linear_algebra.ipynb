# %% [markdown]
# # Линейная алгебра

# %% [markdown]
# [![Текст к картинке](https://img.youtube.com/vi/RNTRYicPvWQ/0.jpg)](https://www.youtube.com/watch?v=RNTRYicPvWQ)

# %% [markdown]
# ## Евклидово пространство

# %% [markdown]
# Евкли́дово простра́нство - это пространство, свойства которого описываются аксиомами евклидовой геометрии.

# %% [markdown]
# ## Вектор

# %% [markdown]
# ***Вектор*** в $n$-мерном евклидовом пространстве $\mathbb{R}^n$ называется упорядоченный набор чисел $x=(x_1,x_2,...,x_n)$ - собственно, элемент пространства $\mathbb{R}^n$.
#
# Обычно, вектор удобнее щаписывать в столбец:
#
# $$
# x =
# \begin{pmatrix}
# x_1\\
# x_2\\
# ...\\
# x_n\\
# \end{pmatrix}
# $$
#
# Вектор - это геометрический обьект который можно отобразить на графике. Геометрическое определение вектора следующее:
#
# ***Вектор*** -  вектор есть направленный отрезок прямой имеющий длинну в евклидовом пространстве.

# %% [markdown]
# [![Текст к картинке](https://img.youtube.com/vi/TJGH_5VMAL4/0.jpg)](https://www.youtube.com/watch?v=TJGH_5VMAL4)

# %% [markdown]
# ### Действия над векторами

# %% [markdown]
# #### Умножение вектора на скаляр

# %% [markdown]
# При умножении вектора $\vec{b} = (x_1,x_2,...,x_n)$  на скаляр $a$ каждый из компонентов этого вектора умножается на скаляр $a$:
# $$
# a
# *
# \begin{pmatrix}
# x_1\\
# x_2\\
# ...\\
# x_n\\
# \end{pmatrix}
# =
# \begin{pmatrix}
# a(x_1)\\
# a(x_2)\\
# ...\\
# a(x_n)\\
# \end{pmatrix}
# $$
#
# Геометрический смысл умножения вектора на скаляр - увеличение длинны вектора в $a$ раз.

# %% [markdown]
# ##### Геометрический смысл

# %% [markdown]
# ###### Правило треугольника
#
# Для того чтобы получить сумму двух векторов, нужно из произвольной точки отложить первый вектор, из конца полученного вектора отложить второй вектор, и построить вектор, соединяющий начало первого с концом второго – это и будет сумма двух векторов.
#
# ######  Правило параллелограмма
#
# Чтобы получить сумму двух векторов, нужно из произвольной точки отложить эти два вектора и построить на них параллелограмм. Диагональ параллелограмма, исходящая из начальной точки, и будет суммой заданных векторов.

# %% [markdown]
# #### Сложение векторов

# %% [markdown]
# Сумма векторов $\vec{a} = (a_1,a_2,...,a_n)$ и $\vec{b} = (b_1,b_2,...,b_n)$ представляет собой сумму соответствующих координат векторов $\vec{a}$ $\vec{b}$:
# $$
# \begin{pmatrix}
# a_1\\
# a_2\\
# ...\\
# a_n\\
# \end{pmatrix}
# +
# \begin{pmatrix}
# b_1\\
# b_2\\
# ...\\
# b_n\\
# \end{pmatrix}
# =
# \begin{pmatrix}
# (a_1+b_2)\\
# (a_2+b_2)\\
# ...\\
# (a_n+b_n)\\
# \end{pmatrix}
# $$

# %% [markdown]
# ##### Геометрический смысл

# %% [markdown]
# НАДО СДЕЛАТЬ!

# %% [markdown]
# ## Линейные пространства

# %% [markdown]
# Векторное пространство $\mathbb{R}^n$ ***замкнуто*** относительно операций сложения и умножения на скаляр. То есть при сложении двух векторов или умножении вектора на число мы в любом случае получим вектор. Иными словами, эти операции не позволяют нам выйти за пределы векторного пространства.

# %% [markdown]
# ### Линейное (векторное) подпространство

# %% [markdown]
# # ОСТАНОВИЛСЯ НА

# %% [markdown]
# 1.3 Дополнительные материалы для самостоятельного освоения
# Ликбез по линейной алгебре Часть 1
#
# 6:38
